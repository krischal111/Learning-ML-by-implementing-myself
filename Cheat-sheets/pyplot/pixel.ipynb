# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
data = np.random.random((4,10))
data
# Out:
# array([[0.06197644, 0.16156678, 0.52654784, 0.24112484, 0.88129639,
#         0.21488695, 0.93095425, 0.14682625, 0.824775  , 0.82056868],
#        [0.98242965, 0.55541033, 0.93181473, 0.99197733, 0.08824281,
#         0.08680377, 0.52647997, 0.22451786, 0.26420234, 0.64284478],
#        [0.02722457, 0.81814645, 0.431569  , 0.87374456, 0.64666012,
#         0.50629825, 0.33256189, 0.44301398, 0.02607007, 0.27532112],
#        [0.6013964 , 0.46120958, 0.44222438, 0.74983405, 0.02490194,
#         0.13093164, 0.63932291, 0.58620218, 0.20398622, 0.45916855]])

# %%
pixel_plot = plt.figure()
plt.imshow(data)

# %%
plt.imshow(data)
# adds a colorbar to the side
plt.colorbar()
# adds a title
plt.title("A random pixel plot")
# Out:
# Text(0.5, 1.0, 'A random pixel plot')
